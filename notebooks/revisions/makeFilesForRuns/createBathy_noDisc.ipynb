# %%
import numpy as np
from matplotlib import pyplot as plt
import netCDF4 as nc
import re
import shutil
# %matplotlib inline

# %%
src='/ocean/eolson/MEOPAR/northernNO3PaperCalcs/bioModel/runFiles/bathymetry_201702.nc'
dst='/ocean/eolson/MEOPAR/northernNO3PaperCalcs/bioModel/runFiles/bathymetry_201702_noDisc.nc'

# %%
shutil.copy(src, dst)
# Out:
# '/ocean/eolson/MEOPAR/northernNO3PaperCalcs/bioModel/runFiles/bathymetry_201702_noDisc.nc'

# %%
f=nc.Dataset(dst,'r+')

# %%
print(f.variables.keys())
# Out:
# odict_keys(['nav_lon', 'nav_lat', 'Bathymetry'])

# %%
fig,ax=plt.subplots(1,1,figsize=(5,6))
ax.pcolormesh(f.variables['Bathymetry'][700:,50:200])

# %%
f.variables['Bathymetry'][875,50:90]
# Out:
# masked_array(data=[--, --, --, --, --, --, --, --, --, --, 84.1875,
#                    127.3125, 189.1875, 150.125, 134.375, 130.6875, 95.5,
#                    46.125, --, --, --, --, --, --, --, --, 22.3125,
#                    19.4375, --, --, --, --, --, --, --, --, 85.0,
#                    118.8125, 124.6875, 156.3125],
#              mask=[ True,  True,  True,  True,  True,  True,  True,  True,
#                     True,  True, False, False, False, False, False, False,
#                    False, False,  True,  True,  True,  True,  True,  True,
#                     True,  True, False, False,  True,  True,  True,  True,
#                     True,  True,  True,  True, False, False, False, False],
#        fill_value=0.0)

# %%
f.variables['Bathymetry'][875,50:90].mask
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True, False, False, False, False, False, False, False, False,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False])

# %%
f.variables['Bathymetry'][840:,:115]=0.0

# %%
fig,ax=plt.subplots(1,1,figsize=(5,6))
ax.pcolormesh(f.variables['Bathymetry'][700:,50:200])

# %%
f.variables['Bathymetry'][750:845,:135]=0.0

# %%
fig,ax=plt.subplots(1,1,figsize=(5,6))
ax.pcolormesh(f.variables['Bathymetry'][700:,50:200])

# %%
f.variables['Bathymetry'][780:830,:142]=0.0

# %%
fig,ax=plt.subplots(1,1,figsize=(5,6))
ax.pcolormesh(f.variables['Bathymetry'][700:,50:200])

# %%
f.variables['Bathymetry'][734:760,:132]=0.0

# %%
fig,ax=plt.subplots(1,1,figsize=(5,6))
ax.pcolormesh(f.variables['Bathymetry'][700:,50:200])

# %%
f.close()

# %%
f=nc.Dataset(dst)

# %%
plt.pcolormesh(f.variables['Bathymetry'])

# %%
f.close()
